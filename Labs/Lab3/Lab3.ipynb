# %%
import matplotlib.pyplot as plt
import numpy as np

horizontal_side = []
vertical_side = []

with open("unlabelled_data.csv", "r") as unlabelled_data:
     for each_unlabelled_data in unlabelled_data:
         splited_each_unlabelled_data = each_unlabelled_data.split(",")
         horizontal_side.append(float(splited_each_unlabelled_data[0]))
         vertical_side.append(float(splited_each_unlabelled_data[1]))



         
# Creating a scatter plot for Unlabbeled Data
plt.scatter(vertical_side, horizontal_side, color="orange", label="Unlabbeled Data")
# Labeling the axes
plt.xlabel("Left")        
plt.ylabel("Right)")   
# Axes values with increment of 1. And 
x_values = tuple(range(-6, 6))
y_values = tuple(range(-6, 6))
# Axes ticks to show the values
plt.xticks(x_values)
plt.yticks(y_values)
# Adds Legends to show explain the dot aka scatter represents Unlabbeled Data
plt.legend()
# Adds the grid to easier see where the dots are in the axes
plt.grid()
# Displaying the plot
plt.plot(xpoints, ypoints)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 32
#      30 plt.grid()
#      31 # Displaying the plot
# ---> 32 plt.plot(xpoints, ypoints)
#
# NameError: name 'xpoints' is not defined
